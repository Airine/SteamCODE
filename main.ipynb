# %%
import pandas as pd
import numpy as np
import urllib.request
import os
from progressbar import ProgressBar
import networkx as nx
import matplotlib.pyplot as plt
from matplotlib import colors as mcolors
import PIL.ImageOps    
from PIL import Image
import itertools
import math
import sys
from shutil import copyfile

html_src = './results/simple_AE_2d_11/index.html'
result_path = './results/'

def constract_graph(source, target, weight):
    if not len(source)==len(target)==len(weight):
        raise Exception('Source, target and weight not match.')
    G = nx.Graph()
    for i in range(len(source)):
        G.add_edge(source[i], target[i], weight=weight[i])
    return G

def p2f(x):
    return float(x.strip('%'))/100

# %%
price = pd.read_csv('data/price.csv')
price.rename(columns={'AppID':'id'}, inplace=True)
price.set_index('id', inplace=True)

# %%
detail = pd.read_csv('data/detail.csv')
detail.rename(columns={'AppID':'id'}, inplace=True)
detail.set_index('id', inplace=True)

# %%
more_info = pd.read_csv('data/id.csv')
more_info.set_index('id', inplace=True)
more_info = more_info.fillna(0)
more_info["ser_id"] = pd.to_numeric(more_info["ser_id"], downcast='integer')
on_sale = pd.read_csv('data/discount.csv')
on_sale.rename(columns={'AppID':'id'}, inplace=True)
on_sale.set_index('id', inplace=True)
detail = detail.join(more_info)
detail = detail.join(on_sale)

# %%
game_data = pd.read_csv('data/total_data.csv',  converters={'Rating':p2f})
game_data.set_index('AppID', inplace=True)

# %%
game_data
# Out:
#                                            Name   Positive Negative  Rating  \
# AppID
# 10                               Counter-Strike    133,134    3,541  0.9606
# 20                        Team Fortress Classic      3,591      670  0.8151
# 30                                Day of Defeat      3,623      435  0.8606
# 40                           Deathmatch Classic      1,365      290  0.7899
# 50                    Half-Life: Opposing Force      5,670      314  0.9149
# 60                                     Ricochet      2,962      717  0.7793
# 70                                    Half-Life     30,813    1,167  0.9431
# 80               Counter-Strike: Condition Zero     13,229    1,499  0.8761
# 130                       Half-Life: Blue Shift      4,168      461  0.8689
# 220                                 Half-Life 2     72,913    2,488  0.9511
# 240                      Counter-Strike: Source     85,237    3,742  0.9431
# 280                           Half-Life: Source      4,135    1,120  0.7651
# 300                       Day of Defeat: Source     11,188    1,273  0.8746
# 320                     Half-Life 2: Deathmatch      6,361      809  0.8604
# 340                     Half-Life 2: Lost Coast      6,035    1,045  0.8280
# 360                Half-Life Deathmatch: Source      1,476      489  0.7255
# 380                    Half-Life 2: Episode One      8,403      536  0.9116
# 400                                      Portal     55,948    1,125  0.9625
# 420                    Half-Life 2: Episode Two     14,571      703  0.9290
# 440                             Team Fortress 2    546,283   35,742  0.9305
# 500                                 Left 4 Dead     20,048    1,030  0.9286
# 550                               Left 4 Dead 2    273,711    8,878  0.9579
# 570                                      Dota 2    901,112  149,244  0.8524
# 620                                    Portal 2    152,353    2,034  0.9735
# 630                                 Alien Swarm     17,745      967  0.9251
# 730            Counter-Strike: Global Offensive  2,829,388  424,485  0.8655
# 1002                           Rag Doll Kung Fu         41       17  0.6463
# 1200              Red Orchestra: Ostfront 41-45      1,619      233  0.8353
# 1230                               Mare Nostrum        141       17  0.8071
# 1250                              Killing Floor     54,902    2,698  0.9364
# ...                                         ...        ...      ...     ...
# 1102980                                   英雄群侠传         12        3  0.6698
# 1103040           Bepuzzled Space Jigsaw Puzzle          0        1  0.4058
# 1103210                We Become What We Behold          2        3  0.4583
# 1103320                              Snow Arena          7        3  0.6028
# 1103430                              Detonation          0        1  0.4058
# 1103590                                 蹩脚的炼金术师          2        4  0.4261
# 1103630                Event Horizon - Frontier          3        3  0.5000
# 1103690                             Interregnum          0        2  0.3592
# 1103870                             Space Dance          3        0  0.6706
# 1103940                Virtual Debating Chamber          2        1  0.5569
# 1104170                            Cosmo Chaser          0        2  0.3592
# 1104220                          Kyle Simulator         46        5  0.7796
# 1104230                 The Last Escape of Yeti          6        1  0.6662
# 1104390             Ravenfield: Multiplayer Mod        185       63  0.6992
# 1104460                        Gourmet Warriors          1        0  0.5942
# 1104590                                Bacillus          4        1  0.6251
# 1104830      Mystery Masterpiece: The Moonstone          2        1  0.5569
# 1105300                                The Cube          1        0  0.5942
# 1105390                             Sailor Jump          1        0  0.5942
# 1105620                                 Exertus         10        0  0.7571
# 1105770                                     THC          3        1  0.5960
# 1106060                 Attack it! Devil legion         18        3  0.7163
# 1106150                  Yet Another Hero Story          2        0  0.6408
# 1106350                                   Pyrax          4        0  0.6920
# 1106850  Totally Reliable Delivery Service Beta      1,302      105  0.8774
# 1107490       The Searchers of Legends : Origin          1        2  0.4431
# 1108400                   Cyberprank Girls 2077          9       12  0.4567
# 1110490                             LAB Defence          1        0  0.5942
# 1110840              KEIKA - A Puzzle Adventure          3        0  0.6706
# 1111030                        Hentai Bad Girls          2        0  0.6408
#
#          Current 24h Peak All-Time Peak
# AppID
# 10         6,299   14,655       319,586
# 20            32      102         1,897
# 30            41      149         7,758
# 40             6       20           629
# 50            85      171           254
# 60             7       19            95
# 70           461      933         2,167
# 80           285      676        32,748
# 130           44      113           174
# 220          790    1,502        12,953
# 240        2,710    6,138       100,056
# 280           75      153           452
# 300          215      714         7,507
# 320          113      255         2,702
# 340           14       38           180
# 360           13       27            79
# 380          119      245           792
# 400          458      938        20,672
# 420          147      301         1,308
# 440       43,464   56,744       122,938
# 500          322      820        30,616
# 550       10,171   17,645       162,399
# 570      427,384  700,220     1,295,114
# 620        2,820    5,534        98,460
# 630           35       76        60,467
# 730      339,976  557,663       854,801
# 1002         NaN      NaN           NaN
# 1200          11       49           126
# 1230           1        4           298
# 1250         206      497        24,107
# ...          ...      ...           ...
# 1102980        9       11            16
# 1103040      NaN      NaN           NaN
# 1103210      NaN      NaN           NaN
# 1103320      NaN      NaN           NaN
# 1103430      NaN      NaN           NaN
# 1103590      NaN      NaN           NaN
# 1103630        3        6             7
# 1103690      NaN      NaN           NaN
# 1103870      NaN      NaN           NaN
# 1103940      NaN      NaN           NaN
# 1104170      NaN      NaN           NaN
# 1104220      NaN      NaN           NaN
# 1104230      NaN      NaN           NaN
# 1104390       95      246           247
# 1104460      NaN      NaN           NaN
# 1104590      NaN      NaN           NaN
# 1104830      NaN      NaN           NaN
# 1105300        1        2             2
# 1105390      NaN      NaN           NaN
# 1105620        1        5            10
# 1105770      NaN      NaN           NaN
# 1106060        5        9            11
# 1106150        3        8             8
# 1106350        1        2             4
# 1106850       71      138           823
# 1107490      NaN      NaN           NaN
# 1108400        1        8            11
# 1110490        1        2             2
# 1110840        1        4             4
# 1111030        5        6             6
#
# [29729 rows x 7 columns]

# %%
files = [f for f in os.listdir(result_path) if not os.path.isfile(f)]

# %%
files
# Out:
# ['simple_AE_100d_16',
#  'simple_AE_80d_10',
#  'vgg_50d_11',
#  'simple_AE_90d_9_degree',
#  'simple_AE_5d_12',
#  'simple_AE_40d_9_degree',
#  'vgg_30d_8',
#  'simple_AE_30d_10_degree',
#  'simple_AE_50d_67',
#  'vgg_10d_7',
#  'vgg_20d_6',
#  'simple_AE_2d_11_degree',
#  'simple_AE_60d_13',
#  'simple_AE_70d_27_degree',
#  'simple_AE_70d_13',
#  'simple_AE_20d_11_degree',
#  'vgg_5d_8',
#  'simple_AE_5d_12_degree',
#  'simple_AE_100d_13',
#  'simple_AE_2d_11',
#  'simple_AE_40d_13',
#  'simple_AE_80d_26_degree',
#  'simple_AE_50d_7_degree',
#  'simple_AE_90d_12',
#  'simple_AE_100d_5_degree',
#  'vgg_100d_5',
#  'vgg_3d_6',
#  'simple_AE_3d_8_degree',
#  'vgg_200d_6',
#  'simple_AE_20d_12',
#  'simple_AE_60d_6_degree',
#  'vgg_2d_10',
#  'simple_AE_3d_9',
#  'simple_AE_30d_13']

# %%
pbar = ProgressBar()
for file in pbar(files):
    target = result_path+file+'/'
    edges = pd.read_csv(target+'edge.csv')
    nodes = pd.read_csv(target+'node.csv')
    edges.rename(columns={'Source':'source',
                          'Target':'target',
                          'Weight':'weight'},
                 inplace=True)
    nodes.rename(columns={'Id':'id', 'modularity_class':'group'},
                 inplace=True)
    nodes.set_index('id',inplace=True)
    edges.drop(columns=['Type', 'Id', 'Label', 'timeset'], inplace=True)
    nodes.drop(columns=['Label', 'timeset'], inplace=True)
    G = constract_graph(list(edges['source']), list(edges['target']), list(edges['weight']))
    constrains = pd.read_csv(target+'parameter.csv')
    w_threhold = 0
    d_threhold = 0
    try:
        pre_edges = nx.number_of_edges(G)
        w_threhold = constrains.loc[0]['weight']
        remove_edges = list()
        G_weights = nx.get_edge_attributes(G, 'weight')
        for edge in nx.edges(G):
            if G_weights[edge] > w_threhold:
                remove_edges.append(edge)
        G.remove_edges_from(remove_edges)
        aft_edges = nx.number_of_edges(G)
#         print(str(pre_edges)+' edges->'+str(aft_edges)+' edges.')
    except:
#         print('no weight constrain')
        pass
    try:
        pre_nodes = nx.number_of_nodes(G)
        d_threhold = constrains.loc[0]['degree']
        remove = [node for node,degree in G.degree() if degree > d_threhold]
        G.remove_nodes_from(remove)
        aft_nodes = nx.number_of_nodes(G)
#         print(str(pre_nodes)+' nodes->'+str(aft_nodes)+' nodes.')
    except:
#         print('no degree constrain')
        pass
    nx.write_weighted_edgelist(G, target+'tempt.csv', delimiter=',')
    new_edges = pd.read_csv(target+'tempt.csv', header=None).rename(columns={0:'source',1:'target',2:'weight'})
    new_nodes = pd.DataFrame(list(nx.nodes(G))).rename(columns={0:'id'}).set_index('id')
    new_nodes = new_nodes.join(nodes)
    new_nodes = new_nodes.join(price)
    new_nodes = new_nodes.join(detail)
    new_nodes = new_nodes.join(game_data)
    new_nodes.index.name = 'id'
    new_edges.to_csv(target+'pro_edges.csv', index=False)
    new_nodes.rename(columns={"24h Peak":"24hPeak","All-Time Peak":"AllTime"})
    new_nodes.to_csv(target+'pro_nodes.csv', index=True)
    try:
        copyfile(html_src, target+'index.html')
    except:
        pass
#         print('same file error')
#     print(target+' completed.')
# Out:
# 100% |########################################################################|

# %%
constrains = pd.read_csv(target+'parameter.csv')

# %%
new_nodes
# Out:
#          group  price                               company  date     tag  \
# id
# 10          73   9.99                                 Valve  2000    1774
# 50          48   4.99                                 Valve  1999    4667
# 70          35   9.99                                 Valve  1998    4667
# 130         59   4.99                                 Valve  2001    4667
# 220         59   9.99                                 Valve  2004    4667
# 240         59   9.99                                 Valve  2004    1774
# 280         35   9.99                                 Valve  2004    4667
# 320          2   4.99                                 Valve  2004    4667
# 340         12   0.00                                 Valve  2005    4667
# 360         36   9.99                                 Valve  2006    4667
# 380         35   7.99                                 Valve  2006    4667
# 420         59   7.99                                 Valve  2007    4667
# 550         70   9.99                                 Valve  2009    3978
# 630         63   0.00                                 Valve  2010    1755
# 730         15   0.00                                 Valve  2012    1774
# 730         15   0.00                                 Valve  2012    1678
# 3590        59   4.99                    PopCap Games, Inc.  2009    1645
# 3900        32   7.49                                    2K  2005       9
# 3910        19   4.99                                    2K  2001       9
# 4570        30  12.99                                  SEGA  2006    4345
# 7000        65   6.99                           Square Enix  2006    4667
# 7520         2  19.99              Topware Interactive, ACE  2011    4604
# 8000        69   8.99                           Square Enix  2007    4667
# 8140        58   8.99                           Square Enix  2008    4667
# 8800        73   7.49                                    2K  2007       9
# 8930        59  29.99                                    2K  2010       9
# 10090       59  19.99                            Activision  2008    1678
# 12100       59   9.99                        Rockstar Games  2002     699
# 12110       69   9.99                        Rockstar Games  2003     699
# 12120       59  14.99                        Rockstar Games  2005     699
# ...        ...    ...                                   ...   ...     ...
# 819080      73   4.99                 Burning Asphalt Group  2018  123332
# 819630      59   9.99                             Namo Gamo  2018    1746
# 831250      38   2.99                          Gamesandapps  2018   17927
# 834910      59  29.99                       Grapeshot Games  2018    1681
# 838390       4   0.50                 Anatoliy Loginovskikh  2018    4667
# 841370      59  59.99                                    2K  2018    1746
# 851940      55   5.99                              dev4play  2018  198913
# 858210      12  12.74                              Pixeljam  2019    1755
# 865090      59   0.59                  Oppai Reveal Studios  2018    5611
# 865090      59   0.59                  Oppai Reveal Studios  2018    5611
# 877180      59   0.99                           Right Games  2018    4726
# 880470      39  24.99                          Umix Studios  2018    1746
# 883710      15  59.99                      CAPCOM Co., Ltd.  2019    3978
# 890970      19   2.99                   Breaking Dimensions  2018    3978
# 894940      48  14.99                            SmashGames  2019    3964
# 906870      61   0.00                               Demibug  2019    6815
# 911400      12  39.99                 Ubisoft Entertainment  2019    4667
# 948630      59   0.59                        LeonWaan Games  2018    5611
# 951740      59   6.99                     PolyGryph Studios  2018    7038
# 958260      59   0.00            KOEI TECMO GAMES CO., LTD.  2019    5611
# 961440       9   0.00                      CAPCOM Co., Ltd.  2019    3978
# 967050      35   4.99                              SKH Apps  2019    3978
# 1049660     16   0.00                            pg5-Studio  2019    3964
# 1054580     59   0.00                               XiMiGua  2019    4726
# 1057720     39   0.00  Breda University of Applied Sciences  2019    3978
# 1070040     12   3.99                        LeonWaan Games  2019    5611
# 1072610     59  14.99                            FistikTech  2019    4726
# 1079420      8   9.99                          Kimble Games  2019  198913
# 1089350     52  59.99                                     0  2019    1746
# 1096010     59   0.99                        LeonWaan Games  2019    5611
#
#          ser_id  discount                                               Name  \
# id
# 10            0       1.0                                     Counter-Strike
# 50            6       1.0                          Half-Life: Opposing Force
# 70            6       1.0                                          Half-Life
# 130           6       1.0                              Half-Life: Blue Shift
# 220           6       1.0                                        Half-Life 2
# 240           0       1.0                             Counter-Strike: Source
# 280           6       1.0                                  Half-Life: Source
# 320           6       1.0                            Half-Life 2: Deathmatch
# 340           6       0.0                            Half-Life 2: Lost Coast
# 360           6       1.0                       Half-Life Deathmatch: Source
# 380           6       1.0                           Half-Life 2: Episode One
# 420           6       1.0                           Half-Life 2: Episode Two
# 550           0       1.0                                      Left 4 Dead 2
# 630           0       0.0                                        Alien Swarm
# 730           0       0.0                   Counter-Strike: Global Offensive
# 730           0       0.0                   Counter-Strike: Global Offensive
# 3590          0       1.0               Plants vs. Zombies: Game of the Year
# 3900          1       0.0                        Sid Meier's Civilization IV
# 3910          1       0.0             Sid Meier's Civilization III: Complete
# 4570          0       0.0  Warhammer 40,000: Dawn of War - Game of the Ye...
# 7000          4       1.0                                Tomb Raider: Legend
# 7520          0       0.0                                      Two Worlds II
# 8000          4       1.0                           Tomb Raider: Anniversary
# 8140          4       1.0                            Tomb Raider: Underworld
# 8800          1       0.0      Sid Meier's Civilization IV: Beyond the Sword
# 8930          1       0.0                         Sid Meier's Civilization V
# 10090         0       0.0                         Call of Duty: World at War
# 12100         3       1.0                               Grand Theft Auto III
# 12110         3       1.0                        Grand Theft Auto: Vice City
# 12120         3       0.0                      Grand Theft Auto: San Andreas
# ...         ...       ...                                                ...
# 819080        0       0.0                                     Moto Racing 3D
# 819630        0       0.0                                Basketball Classics
# 831250        0       0.0                               Maxi Pool Masters VR
# 834910        0       0.0                                              ATLAS
# 838390        0       0.0                                        Merry Glade
# 841370        0       0.0                                           NBA 2K19
# 851940        0       0.0                                 Dirt Bike Insanity
# 858210        0       0.0                                         Nova Drift
# 865090        0       1.0                                             AHEGAL
# 865090        0       1.0                                             AHEGAL
# 877180        0       0.0                                              Candy
# 880470        0       0.0                        Pro Basketball Manager 2019
# 883710        7       1.0                   RESIDENT EVIL 2 / BIOHAZARD RE:2
# 890970        0       0.0                                            Oakwood
# 894940        0       0.0                                         Littlewood
# 906870        0       0.0                                          FurryFury
# 911400        2       1.0                    Assassin's Creed III Remastered
# 948630        0       1.0                                 Hentai MineSweeper
# 951740        0       0.0                    Nice Shot! The Gun Golfing Game
# 958260        0       0.0                DEAD OR ALIVE Xtreme Venus Vacation
# 961440        7       0.0                                                NaN
# 967050        0       1.0                                             Pacify
# 1049660       0       0.0                                        stein.world
# 1054580       0       0.0                                                NaN
# 1057720       0       0.0                                   Shattered Lights
# 1070040       0       0.0                                                NaN
# 1072610       0       0.0                                                NaN
# 1079420       0       0.0                                    Wheelie King VR
# 1089350       0       0.0                                                NaN
# 1096010       0       0.0                                      Hentai Sudoku
#
#           Positive Negative  Rating  Current 24h Peak All-Time Peak
# id
# 10         133,134    3,541  0.9606    6,299   14,655       319,586
# 50           5,670      314  0.9149       85      171           254
# 70          30,813    1,167  0.9431      461      933         2,167
# 130          4,168      461  0.8689       44      113           174
# 220         72,913    2,488  0.9511      790    1,502        12,953
# 240         85,237    3,742  0.9431    2,710    6,138       100,056
# 280          4,135    1,120  0.7651       75      153           452
# 320          6,361      809  0.8604      113      255         2,702
# 340          6,035    1,045  0.8280       14       38           180
# 360          1,476      489  0.7255       13       27            79
# 380          8,403      536  0.9116      119      245           792
# 420         14,571      703  0.9290      147      301         1,308
# 550        273,711    8,878  0.9579   10,171   17,645       162,399
# 630         17,745      967  0.9251       35       76        60,467
# 730      2,829,388  424,485  0.8655  339,976  557,663       854,801
# 730      2,829,388  424,485  0.8655  339,976  557,663       854,801
# 3590        17,556      534  0.9459    1,251    1,653         6,208
# 3900         1,461      137  0.8693      332      589         2,314
# 3910         2,703      412  0.8351      611    1,077         4,600
# 4570         3,651      212  0.9081      120      234         3,241
# 7000         1,750      255  0.8350       14       50           287
# 7520         3,150    2,080  0.5945      134      426         4,812
# 8000         2,099      404  0.8065       26       68           461
# 8140         1,916      624  0.7303       26       55           415
# 8800         1,502       71  0.9053      730    1,266         2,475
# 8930       134,449    5,671  0.9466   13,770   23,631        91,363
# 10090       20,884    1,541  0.9101      613    1,025         4,825
# 12100        5,095      795  0.8383       83      176           640
# 12110       10,748      862  0.9003      181      409           814
# 12120       30,366    3,387  0.8823      839    1,981         2,443
# ...            ...      ...     ...      ...      ...           ...
# 819080           0        3  0.3294      NaN      NaN           NaN
# 819630          38        3  0.7883      NaN      NaN           NaN
# 831250           7        2  0.6389      NaN      NaN           NaN
# 834910       9,458   16,907  0.3653    1,616    3,666        58,939
# 838390         114        2  0.8676      NaN      NaN           NaN
# 841370       5,606   10,344  0.3595   15,553   25,633        29,202
# 851940           3        5  0.4395      NaN      NaN           NaN
# 858210         537        4  0.9186       34       65           251
# 865090         539       68  0.8316        1        4           149
# 865090         539       68  0.8316        1        4           149
# 877180           3        0  0.6706      NaN      NaN           NaN
# 880470          17       13  0.5430        1        8            24
# 883710      29,040    1,167  0.9407      802    1,232        74,227
# 890970          72       18  0.7228      NaN      NaN           NaN
# 894940         333        8  0.8943       38       92           387
# 906870           3        0  0.6706       23       23            23
# 911400         642    1,224  0.3602      116      184         3,561
# 948630         504       84  0.8048        7       13            54
# 951740          32        3  0.7734      NaN      NaN           NaN
# 958260       2,126      995  0.6651    1,253    2,358         7,352
# 961440         NaN      NaN     NaN      NaN      NaN           NaN
# 967050       2,585      341  0.8488       44      143           455
# 1049660        131       96  0.5621        3       19           270
# 1054580        NaN      NaN     NaN      NaN      NaN           NaN
# 1057720         95        6  0.8311      NaN      NaN           NaN
# 1070040        NaN      NaN     NaN      NaN      NaN           NaN
# 1072610        NaN      NaN     NaN      NaN      NaN           NaN
# 1079420          1        2  0.4431      NaN      NaN           NaN
# 1089350        NaN      NaN     NaN      NaN      NaN           NaN
# 1096010         25       11  0.6289      NaN      NaN           NaN
#
# [269 rows x 14 columns]

# %%
G = constract_graph(list(edges['source']), list(edges['target']), list(edges['weight']))

# %%
on_sale
# Out:
# 958260      NaN                DEAD OR ALIVE Xtreme Venus Vacation      2,126
# 961440      7.0                                                NaN        NaN
# 967050      NaN                                             Pacify      2,585
# 1049660     NaN                                        stein.world        131
# 1054580     NaN                                                NaN        NaN
# 1057720     NaN                                   Shattered Lights         95
# 1070040     NaN                                                NaN        NaN
# 1072610     NaN                                                NaN        NaN
# 1079420     NaN                                    Wheelie King VR          1
# 1089350     NaN                                                NaN        NaN
# 1096010     NaN                                      Hentai Sudoku         25
#
#         Negative  Rating  Current 24h Peak All-Time Peak
# 10         3,541  96.06%    6,299   14,655       319,586
# 50           314  91.49%       85      171           254
# 70         1,167  94.31%      461      933         2,167
# 130          461  86.89%       44      113           174
# 220        2,488  95.11%      790    1,502        12,953
# 240        3,742  94.31%    2,710    6,138       100,056
# 280        1,120  76.51%       75      153           452
# 320          809  86.04%      113      255         2,702
# 340        1,045  82.80%       14       38           180
# 360          489  72.55%       13       27            79
# 380          536  91.16%      119      245           792
# 420          703  92.90%      147      301         1,308
# 550        8,878  95.79%   10,171   17,645       162,399
# 630          967  92.51%       35       76        60,467
# 730      424,485  86.55%  339,976  557,663       854,801
# 730      424,485  86.55%  339,976  557,663       854,801
# 3590         534  94.59%    1,251    1,653         6,208
# 3900         137  86.93%      332      589         2,314
# 3910         412  83.51%      611    1,077         4,600
# 4570         212  90.81%      120      234         3,241
# 7000         255  83.50%       14       50           287
# 7520       2,080  59.45%      134      426         4,812
# 8000         404  80.65%       26       68           461
# 8140         624  73.03%       26       55           415
# 8800          71  90.53%      730    1,266         2,475
# 8930       5,671  94.66%   13,770   23,631        91,363
# 10090      1,541  91.01%      613    1,025         4,825
# 12100        795  83.83%       83      176           640
# 12110        862  90.03%      181      409           814
# 12120      3,387  88.23%      839    1,981         2,443
# ...          ...     ...      ...      ...           ...
# 819080         3  32.94%      NaN      NaN           NaN
# 819630         3  78.83%      NaN      NaN           NaN
# 831250         2  63.89%      NaN      NaN           NaN
# 834910    16,907  36.53%    1,616    3,666        58,939
# 838390         2  86.76%      NaN      NaN           NaN
# 841370    10,344  35.95%   15,553   25,633        29,202
# 851940         5  43.95%      NaN      NaN           NaN
# 858210         4  91.86%       34       65           251
# 865090        68  83.16%        1        4           149
# 865090        68  83.16%        1        4           149
# 877180         0  67.06%      NaN      NaN           NaN
# 880470        13  54.30%        1        8            24
# 883710     1,167  94.07%      802    1,232        74,227
# 890970        18  72.28%      NaN      NaN           NaN
# 894940         8  89.43%       38       92           387
# 906870         0  67.06%       23       23            23
# 911400     1,224  36.02%      116      184         3,561
# 948630        84  80.48%        7       13            54
# 951740         3  77.34%      NaN      NaN           NaN
# 958260       995  66.51%    1,253    2,358         7,352
# 961440       NaN     NaN      NaN      NaN           NaN
# 967050       341  84.88%       44      143           455
# 1049660       96  56.21%        3       19           270
# 1054580      NaN     NaN      NaN      NaN           NaN
# 1057720        6  83.11%      NaN      NaN           NaN
# 1070040      NaN     NaN      NaN      NaN           NaN
# 1072610      NaN     NaN      NaN      NaN           NaN
# 1079420        2  44.31%      NaN      NaN           NaN
# 1089350      NaN     NaN      NaN      NaN           NaN
# 1096010       11  62.89%      NaN      NaN           NaN
#
# [269 rows x 13 columns]
